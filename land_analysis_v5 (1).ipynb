# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib import pyplot as plt
from pathlib import Path 
from PIL import Image
from scipy import ndimage, misc
import numpy as np
import cv2
import os
import math

# %%
def remove_noise(imgray):
    ori_imgray = imgray.copy()
    row, col = imgray.shape
    resolution = 4
    
    # invertcolorはいろんな実装方法があるが、例えばnumpyのbroadcastを使えば以下の1行でかけます
    # imgray = 255 - imgray
    # ただし、このあとの処理を見るに、cv2.threshold(imgray, 245, 255, cv2.THRESH_BINARY_INV) でも同じ結果になりそうです
    # (removenoisefun.pngの画像が反転すること以外)
    ret, thresh = cv2.threshold(imgray, 245, 255, cv2.THRESH_BINARY_INV)
    # 今後使わない変数は作成さずに、 _ で受けるという手段があります
    _, contours, _ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)    

    while (len(contours)>1):
        print("resolution",resolution)
        resolution += 1
        imgray = ori_imgray.copy()        

        imgray = resolution_image(imgray, resolution)
        
        ret, thresh = cv2.threshold(imgray,245,255,cv2.THRESH_BINARY_INV)
        _, contours, _ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

    
    # 最初から len(contours) <= 1の場合whileに入らないので、ここでcntを受け取る必要がある
    # また、contoursが空の場合は[0]でアクセスできないので注意
    #get the coordinate from land
    cnt = contours[0] if len(contours)>0 else np.array([[]])
    #print ('contours',contours)       

    # (N, 1, 2) のndarrayを N要素の(x, y)に変換するコードは例えばこのような書き方もあります 
    land_cor = cnt.reshape(-1, 2).tolist()
    
    test_output = os.path.join('./tochi_test37/'+'removenoisefun'+'.png' )
    print("output_path is", test_output)
    # 今までの結果と互換性を保つため、imgrayを反転した画像を保存します
    cv2.imwrite(test_output, 255-imgray)

    return imgray, land_cor, contours

# %%
from itertools import product

def resolution_image(imgray, resolution):    
    row, col = imgray.shape
    
    # ピクセル値が255のピクセルに対して、その周辺を255にする処理はdilationという処理でかけます
    mask = (imgray == 255).astype(np.uint8) * 255
    kernel = np.ones((3, 3),np.uint8)
    dilated = cv2.dilate(mask, kernel, iterations=resolution)
    imgray[dilated.astype(np.bool)] = 255
    
    # 任意のピクセル値(0~254)を膨張するのは少しややこしいが、numpyのwhereとindexing, broadcastingを使った方が多少簡潔になる
    for _ in range (resolution):
        ys, xs = np.where(imgray != 255)
        v = imgray[ys, xs]
        for dy, dx in product([-1, 0, 1], repeat=2):
            imgray[np.clip(ys+dy, 0, row-1), np.clip(xs+dx, 0, col-1)] = v

    # in-place処理ではあるが、一応変換後のnumpy.ndarrayも返却した方がpythonっぽい
    return imgray

# %%
from itertools import product

# %%
list(product([-1, 0, 1], repeat=2))
# Out:
# [(-1, -1), (-1, 0), (-1, 1), (0, -1), (0, 0), (0, 1), (1, -1), (1, 0), (1, 1)]

# %%
def road_detection(new_imgray,ori_imgray):
    # numpyのbroadcastingを使えば簡潔に書けます
    # new_imgray!=255でTrueかFalseが入った配列ができて、
    # fancy_indexingとbroadcastという機能で一括で変更できます
    # 下のセルに例を書いてみました
    ori_imgray[new_imgray!=255] = 255
 
    return ori_imgray

# %%
x = np.random.rand(3, 3)
print(x)
print(x>0.5)
x[x>0.5] = 1
print(x)
# Out:
# [[0.17100255 0.24311748 0.38688406]
#  [0.07308525 0.51422236 0.47207915]
#  [0.26423818 0.28563264 0.41202207]]
# [[False False False]
#  [False  True False]
#  [False False False]]
# [[0.17100255 0.24311748 0.38688406]
#  [0.07308525 1.         0.47207915]
#  [0.26423818 0.28563264 0.41202207]]

# %%
def hough_linedetection(ori_imgray):
 
    backtorgb = cv2.cvtColor(ori_imgray,cv2.COLOR_GRAY2RGB)
    edges = cv2.Canny(backtorgb,100,200,apertureSize = 3)
    minLineLength = 50
    maxLineGap = 10
    threshold = 15
 
    lines = cv2.HoughLinesP(edges,1,np.pi/180,threshold,minLineLength,maxLineGap)
  
    return lines

# %%
def median_filter(land_cor):
    median_result = ndimage.median_filter(imgray, size=(3, 3))
    
    return median_result

# %%
def getPoints(x1, y1, x2, y2, gp_lst):

    if (x1==x2):
        for y in range (y1,y2+1):
                gp_lst.append((x1,y))
    else:
    
        m = (y2-y1) / (x2-x1)
        b = y1 - m * x1
        for x in range(x1, x2+1):
            y = m * x + b
            y=int(y)
            gp_lst.append((x,y))
    #print (gp_lst)
    return gp_lst

# %%
def line_dist(x1,y1,x2,y2):
    x=abs(x1-x2)
    y=abs(y1-y2)
    sum_line=math.sqrt((x**2)+(y**2))
    return sum_line

# %%
"""
この関数については、リファクタリングの余地はあるのですが、それ以前に
returnを書くインデントがおかしいと思いました。
下に print('必ず一回しかこのprintは通りません') を書いたとおり、これは最初のループで必ずreturnしてしまいます
"""
def getMinLengthLineSegment(point_lst):

    min_point=[]
    min_length = line_dist(point_lst[0][0], point_lst[0][1], point_lst[1][0], point_lst[1][1])
    min_point.append(point_lst[0])
    min_point.append(point_lst[1])
    print("min_point is",min_point)

    for i in range(len(point_lst)):
        if (i != len(point_lst)-1):
            x1, y1 = point_lst[i]
            x2, y2 = point_lst[i+1]
            sum_line = line_dist(x1,y1,x2,y2)

            if (sum_line<min_length):
                min_length=sum_line
                min_point[0]=point_lst[i]
                min_point[1]=point_lst[i+1]
                print("min_point is",min_point)
        else:
            x1, y1 = point_lst[i]
            x2, y2 = point_lst[0]
            sum_line = line_dist(x1,y1,x2,y2)

            if (sum_line<min_length):
                min_length=sum_line
                min_point[0]=point_lst[i]
                min_point[1]=point_lst[0]
                print("min_point is",min_point)
                
        print ("min_legth is",min_length) 
        print ("min_point is",min_point) 
        print('必ず一回しかこのprintは通りません')
        return min_length, min_point

# %%
def getMaxLengthLineSegment(point_lst):

    max_point=[]
    max_length = line_dist(point_lst[0][0], point_lst[0][1], point_lst[1][0], point_lst[1][1])
    max_point.append(point_lst[0])
    max_point.append(point_lst[1])

    for i in range(len(point_lst)):
        if (i != len(point_lst)-1):
            x1, y1 = point_lst[i]
            x2, y2 = point_lst[i+1]
            sum_line = line_dist(x1,y1,x2,y2)

            if (sum_line>max_length):
                max_length=sum_line
                max_point[0]=point_lst[i]
                max_point[1]=point_lst[i+1]

        else:
            x1, y1 = point_lst[i]
            x2, y2 = point_lst[0]
            sum_line = line_dist(x1,y1,x2,y2)

            if (sum_line>max_length):
                max_length=sum_line
                max_point[0]=point_lst[i]
                max_point[1]=point_lst[0]
                
                
    print ("max_legth is",max_length) 
    print ("max_point is",max_point)             
    return max_length, max_point

# %%
def Gravity_Center(point_lst):
    # numpyを使うと簡潔に書けます
    GC_x, GC_y = np.mean(np.asarray(point_lst), axis=0).astype(np.int32)
    print(GC_x)
    print(GC_y)
    
    return GC_x,GC_y
        #print('point_lst is',point_lst[i])

# %%
def dist(x1,y1, x2,y2, x3,y3): # x3,y3 is the point
    px = x2-x1
    py = y2-y1

    something = px*px + py*py

    u =  ((x3 - x1) * px + (y3 - y1) * py) / float(something)

    if u > 1:
        u = 1
    elif u < 0:
        u = 0

    x = x1 + u * px
    y = y1 + u * py

    dx = x - x3
    dy = y - y3

    # Note: If the actual distance does not matter,
    # if you only want to compare what this function
    # returns to other results of this function, you
    # can just return the squared distance instead
    # (i.e. remove the sqrt) to gain a little performance

    dist = math.sqrt(dx*dx + dy*dy)
    print (dist)

    return dist

# %%
def enhance_image(imgray):
    print('ENHACE')
    #median_result=median_filter(imgray)
    #output_path = os.path.join('./tochi_test37/'+'median_filter'+'.bmp' )
    #cv2.imwrite(output_path, median_result)
    #print('median print finish')

# %%
def run(img_path):
    """
    img_path: path_lib.Path object. path for input image
    """
    
    # note: opencvのimreadはpath_lib.Pathを受け付けられない
    im = cv2.imread(str(img_path))
    # 元々のコードのようにファイルの存在チェックをするのも悪くはないが、
    # 「ファイルは存在するが、画像ファイルではない」といったケースも考えると、
    # cv2.imreadしてしまって、結果をチェックしてしまったほうが良い
    if im is None:
        raise ValueError('cannot read image: {}'.format(img_path))

    #Gray tone
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    # todo row, colは消す
    row, col = imgray.shape

    # 1. ori_imgrayなどの変数はこのスコープで持っていても使わないので、関数にわたすときに作れば十分
    # 2. row, colはremove_noiseの中でori_imgrayから取得できる
    # 3. 受け取る変数名は意味がわかりやすいものにした方がよい
    noise_removed_imgray, land_cor, contours = remove_noise(imgray.copy())
    road_imgray=road_detection(noise_removed_imgray, imgray.copy())
    
    if len(land_cor) == 0:
        print('土地が見つかりませんでした {}'.format(img_path))
        return
     
    min_length, min_point=getMinLengthLineSegment(land_cor)
    max_length, max_point=getMaxLengthLineSegment(land_cor)
 
    #hough
    backtorgb = cv2.cvtColor(road_imgray,cv2.COLOR_GRAY2RGB)
    hough_lines=hough_linedetection(road_imgray)
    
    for x in range(0, len(hough_lines)):
        for x1,y1,x2,y2 in hough_lines[x]:
            cv2.line(backtorgb,(x1,y1),(x2,y2),(0,255,0),2)
    
    hough_output = os.path.join('./tochi_test37/'+img_path.stem+'_hough'+'.png' )
 
    cv2.imwrite(hough_output, backtorgb)
    ret,thresh = cv2.threshold(noise_removed_imgray,127,255,0)
    
    #get all point from hough
    gp_lst=[]
    for i in range (0,len(hough_lines)):
         for x1,y1,x2,y2 in hough_lines[i]:
                getPoints(x1, y1, x2, y2, gp_lst)
                
    
    #gravity of road 
    GC_x, GC_y=Gravity_Center(gp_lst)
    print ("GC_x, GC_y",GC_x, GC_y)
    
    cv2.line(backtorgb,(0,0),(GC_x, GC_y),(0,255,0),2)
    
    gravity_output = os.path.join('./tochi_test37/'+'gravity_output'+'.png' )
    cv2.imwrite(gravity_output, backtorgb)
    
    #point to line distance
    
    x1,y1=max_point[0]
    x2,y2=max_point[1]
    
    #print ('max_point',type(max_point))
    #print ('min_point',type(min_point))
    
    dist(x1,y1, x2,y2, GC_x, GC_y)
    
    x1,y1=min_point[0]
    x2,y2=min_point[1]
    dist(x1,y1, x2,y2, GC_x, GC_y)

# %%
run(Path('tochi/C62145A23.png'))
# Out:
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[533, 188], [532, 189]]
# min_legth is 1.4142135623730951
# min_point is [[533, 188], [532, 189]]
# 必ず一回しかこのprintは通りません
# max_legth is 15.0
# max_point is [[311, 259], [311, 274]]
# 108
# 346
# GC_x, GC_y 108 346
# 215.3903433304288
# 452.133829745132

# %%
files = Path('tochi').glob('*.png')
for f in files:
    run(f)
# Out:
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[239, 238], [238, 239]]
# min_legth is 1.4142135623730951
# min_point is [[239, 238], [238, 239]]
# 必ず一回しかこのprintは通りません
# max_legth is 135.0
# max_point is [[374, 238], [239, 238]]
# 363
# 344
# GC_x, GC_y 363 344
# 106.0
# 163.1318485152424
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[58, 346], [57, 347]]
# min_legth is 1.4142135623730951
# min_point is [[58, 346], [57, 347]]
# 必ず一回しかこのprintは通りません
# max_legth is 21.0
# max_point is [[52, 375], [73, 375]]
# 336
# 185
# GC_x, GC_y 336 185
# 324.45184542548066
# 321.2553501500014
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[164, 211], [164, 213]]
# min_legth is 2.0
# min_point is [[164, 211], [164, 213]]
# 必ず一回しかこのprintは通りません
# max_legth is 128.0
# max_point is [[450, 457], [450, 329]]
# 362
# 134
# GC_x, GC_y 362 134
# 213.9369065869655
# 212.44528707410763
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[193, 119], [193, 122]]
# min_legth is 3.0
# min_point is [[193, 119], [193, 122]]
# 必ず一回しかこのprintは通りません
# max_legth is 383.0
# max_point is [[186, 126], [186, 509]]
# 325
# 80
# GC_x, GC_y 325 80
# 146.4137971640651
# 137.64083696345355
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[160, 170], [160, 172]]
# min_legth is 2.0
# min_point is [[160, 170], [160, 172]]
# 必ず一回しかこのprintは通りません
# max_legth is 344.0
# max_point is [[158, 403], [502, 403]]
# 258
# 427
# GC_x, GC_y 258 427
# 24.0
# 273.18308878845335
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[231, 174], [228, 177]]
# min_legth is 4.242640687119285
# min_point is [[231, 174], [228, 177]]
# 必ず一回しかこのprintは通りません
# max_legth is 201.0
# max_point is [[199, 408], [400, 408]]
# 88
# 320
# GC_x, GC_y 88 320
# 141.65097952361643
# 200.12246250733574
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[94, 233], [94, 234]]
# min_legth is 1.0
# min_point is [[94, 233], [94, 234]]
# 必ず一回しかこのprintは通りません
# max_legth is 468.0
# max_point is [[94, 369], [562, 369]]
# 51
# 272
# GC_x, GC_y 51 272
# 106.10372283760829
# 57.38466694161429
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[333, 297], [333, 327]]
# min_legth is 30.0
# min_point is [[333, 297], [333, 327]]
# 必ず一回しかこのprintは通りません
# max_legth is 38.0
# max_point is [[333, 327], [371, 327]]
# 271
# 174
# GC_x, GC_y 271 174
# 165.08482668010407
# 137.7425134081704
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[316, 111], [315, 112]]
# min_legth is 1.4142135623730951
# min_point is [[316, 111], [315, 112]]
# 必ず一回しかこのprintは通りません
# max_legth is 233.0
# max_point is [[388, 345], [388, 112]]
# 340
# 352
# GC_x, GC_y 340 352
# 48.507731342539614
# 241.29857024027308
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[242, 71], [242, 73]]
# min_legth is 2.0
# min_point is [[242, 71], [242, 73]]
# 必ず一回しかこのprintは通りません
# max_legth is 114.0
# max_point is [[310, 476], [424, 476]]
# 264
# 509
# GC_x, GC_y 264 509
# 56.61271941887264
# 436.5546930225353
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[277, 223], [276, 224]]
# min_legth is 1.4142135623730951
# min_point is [[277, 223], [276, 224]]
# 必ず一回しかこのprintは通りません
# max_legth is 35.0
# max_point is [[270, 247], [305, 247]]
# 268
# 204
# GC_x, GC_y 268 204
# 43.04648650006177
# 21.02379604162864
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[190, 122], [190, 125]]
# min_legth is 3.0
# min_point is [[190, 122], [190, 125]]
# 必ず一回しかこのprintは通りません
# max_legth is 413.0
# max_point is [[394, 541], [394, 128]]
# 292
# 49
# GC_x, GC_y 292 49
# 129.0155029444136
# 125.4312560727987
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[482, 117], [481, 118]]
# min_legth is 1.4142135623730951
# min_point is [[482, 117], [481, 118]]
# 必ず一回しかこのprintは通りません
# max_legth is 147.0
# max_point is [[334, 119], [187, 119]]
# 160
# 412
# GC_x, GC_y 160 412
# 294.24139749532185
# 435.28955879965696
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[763, 518], [763, 536]]
# min_legth is 18.0
# min_point is [[763, 518], [763, 536]]
# 必ず一回しかこのprintは通りません
# max_legth is 18.0
# max_point is [[763, 518], [763, 536]]
# 495
# 418
# GC_x, GC_y 495 418
# 286.048946860498
# 286.048946860498
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[51, 208], [51, 212]]
# min_legth is 4.0
# min_point is [[51, 208], [51, 212]]
# 必ず一回しかこのprintは通りません
# max_legth is 161.0
# max_point is [[497, 380], [497, 219]]
# 538
# 221
# GC_x, GC_y 538 221
# 41.0
# 487.08315511830216
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[451, 188], [450, 189]]
# min_legth is 1.4142135623730951
# min_point is [[451, 188], [450, 189]]
# 必ず一回しかこのprintは通りません
# max_legth is 200.0
# max_point is [[243, 493], [443, 493]]
# 420
# 336
# GC_x, GC_y 420 336
# 157.0
# 150.02999700059985
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[124, 136], [124, 139]]
# min_legth is 3.0
# min_point is [[124, 136], [124, 139]]
# 必ず一回しかこのprintは通りません
# max_legth is 319.0
# max_point is [[443, 136], [124, 136]]
# 287
# 47
# GC_x, GC_y 287 47
# 89.0
# 185.71483516402236
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[167, 75], [167, 78]]
# min_legth is 3.0
# min_point is [[167, 75], [167, 78]]
# 必ず一回しかこのprintは通りません
# max_legth is 180.0
# max_point is [[657, 77], [477, 77]]
# 728
# 210
# GC_x, GC_y 728 210
# 150.7647173578752
# 576.3202234869084
# resolution 4
# resolution 5
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/C5A178012.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[227, 116], [227, 127]]
# min_legth is 11.0
# min_point is [[227, 116], [227, 127]]
# 必ず一回しかこのprintは通りません
# max_legth is 416.0
# max_point is [[220, 131], [220, 547]]
# 349
# 65
# GC_x, GC_y 349 65
# 144.90341610879986
# 132.23085872821065
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[600, 149], [599, 150]]
# min_legth is 1.4142135623730951
# min_point is [[600, 149], [599, 150]]
# 必ず一回しかこのprintは通りません
# max_legth is 45.0
# max_point is [[554, 151], [509, 151]]
# 467
# 404
# GC_x, GC_y 467 404
# 256.46247288833507
# 286.2516375499012
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[391, 21], [390, 22]]
# min_legth is 1.4142135623730951
# min_point is [[391, 21], [390, 22]]
# 必ず一回しかこのprintは通りません
# max_legth is 209.0
# max_point is [[404, 429], [404, 220]]
# 271
# 497
# GC_x, GC_y 271 497
# 149.37536610833797
# 489.67948701165744
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[188, 149], [188, 233]]
# min_legth is 84.0
# min_point is [[188, 149], [188, 233]]
# 必ず一回しかこのprintは通りません
# max_legth is 219.0
# max_point is [[224, 549], [443, 549]]
# 321
# 91
# GC_x, GC_y 321 91
# 458.0
# 145.09651959988565
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[322, 33], [321, 34]]
# min_legth is 1.4142135623730951
# min_point is [[322, 33], [321, 34]]
# 必ず一回しかこのprintは通りません
# max_legth is 411.0
# max_point is [[376, 450], [376, 39]]
# 321
# 485
# GC_x, GC_y 321 485
# 65.19202405202648
# 451.0
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[314, 73], [313, 74]]
# min_legth is 1.4142135623730951
# min_point is [[314, 73], [313, 74]]
# 必ず一回しかこのprintは通りません
# max_legth is 211.0
# max_point is [[124, 429], [335, 429]]
# 325
# 448
# GC_x, GC_y 325 448
# 19.0
# 374.1924638471491
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[56, 197], [55, 198]]
# min_legth is 1.4142135623730951
# min_point is [[56, 197], [55, 198]]
# 必ず一回しかこのprintは通りません
# max_legth is 38.0
# max_point is [[373, 410], [411, 410]]
# 359
# 375
# GC_x, GC_y 359 375
# 37.69615364994153
# 351.4157082431006
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZ5183025.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZ5183027.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# resolution 75
# resolution 76
# resolution 77
# resolution 78
# resolution 79
# resolution 80
# resolution 81
# resolution 82
# resolution 83
# resolution 84
# resolution 85
# resolution 86
# resolution 87
# resolution 88
# resolution 89
# resolution 90
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CXK183013.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[70, 157], [70, 159]]
# min_legth is 2.0
# min_point is [[70, 157], [70, 159]]
# 必ず一回しかこのprintは通りません
# max_legth is 121.0
# max_point is [[422, 291], [422, 170]]
# 426
# 310
# GC_x, GC_y 426 310
# 19.4164878389476
# 386.700142229092
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[462, 175], [461, 176]]
# min_legth is 1.4142135623730951
# min_point is [[462, 175], [461, 176]]
# 必ず一回しかこのprintは通りません
# max_legth is 22.0
# max_point is [[661, 546], [661, 524]]
# 170
# 583
# GC_x, GC_y 170 583
# 492.3921201644072
# 500.3298911718148
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[51, 198], [51, 199]]
# min_legth is 1.0
# min_point is [[51, 198], [51, 199]]
# 必ず一回しかこのprintは通りません
# max_legth is 36.0
# max_point is [[87, 198], [51, 198]]
# 326
# 276
# GC_x, GC_y 326 276
# 251.40604606890423
# 285.57660968643773
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[211, 161], [211, 163]]
# min_legth is 2.0
# min_point is [[211, 161], [211, 163]]
# 必ず一回しかこのprintは通りません
# max_legth is 19.0
# max_point is [[413, 558], [432, 558]]
# 242
# 72
# GC_x, GC_y 242 72
# 515.2057841290216
# 94.2443632266673
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZH182038.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZ5183026.png
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[462, 134], [461, 135]]
# min_legth is 1.4142135623730951
# min_point is [[462, 134], [461, 135]]
# 必ず一回しかこのprintは通りません
# max_legth is 358.0
# max_point is [[549, 497], [549, 139]]
# 69
# 302
# GC_x, GC_y 69 302
# 480.0
# 426.09036600233054
# resolution 4
# resolution 5
# resolution 6
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[62, 2], [62, 3]]
# min_legth is 1.0
# min_point is [[62, 2], [62, 3]]
# 必ず一回しかこのprintは通りません
# max_legth is 404.0
# max_point is [[58, 5], [58, 409]]
# 114
# 477
# GC_x, GC_y 114 477
# 88.09086218218096
# 476.84378993544624
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[306, 381], [306, 383]]
# min_legth is 2.0
# min_point is [[306, 381], [306, 383]]
# 必ず一回しかこのprintは通りません
# max_legth is 241.0
# max_point is [[209, 566], [450, 566]]
# 246
# 115
# GC_x, GC_y 246 115
# 451.0
# 272.6829660979945
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# resolution 75
# resolution 76
# resolution 77
# resolution 78
# resolution 79
# resolution 80
# resolution 81
# resolution 82
# resolution 83
# resolution 84
# resolution 85
# resolution 86
# resolution 87
# resolution 88
# resolution 89
# resolution 90
# resolution 91
# resolution 92
# resolution 93
# resolution 94
# resolution 95
# resolution 96
# resolution 97
# resolution 98
# resolution 99
# resolution 100
# resolution 101
# resolution 102
# resolution 103
# resolution 104
# resolution 105
# resolution 106
# resolution 107
# resolution 108
# resolution 109
# resolution 110
# resolution 111
# resolution 112
# resolution 113
# resolution 114
# resolution 115
# resolution 116
# resolution 117
# resolution 118
# resolution 119
# resolution 120
# resolution 121
# resolution 122
# resolution 123
# resolution 124
# resolution 125
# resolution 126
# resolution 127
# resolution 128
# resolution 129
# resolution 130
# resolution 131
# resolution 132
# resolution 133
# resolution 134
# resolution 135
# resolution 136
# resolution 137
# resolution 138
# resolution 139
# resolution 140
# resolution 141
# resolution 142
# resolution 143
# resolution 144
# resolution 145
# resolution 146
# resolution 147
# resolution 148
# resolution 149
# resolution 150
# resolution 151
# resolution 152
# resolution 153
# resolution 154
# resolution 155
# resolution 156
# resolution 157
# resolution 158
# resolution 159
# resolution 160
# resolution 161
# resolution 162
# resolution 163
# resolution 164
# resolution 165
# resolution 166
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[0, 0], [0, 168]]
# min_legth is 168.0
# min_point is [[0, 0], [0, 168]]
# 必ず一回しかこのprintは通りません
# max_legth is 209.0
# max_point is [[209, 0], [0, 0]]
# 310
# 514
# GC_x, GC_y 310 514
# 523.8291706272189
# 464.56000688823826
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[218, 141], [218, 143]]
# min_legth is 2.0
# min_point is [[218, 141], [218, 143]]
# 必ず一回しかこのprintは通りません
# max_legth is 295.0
# max_point is [[382, 577], [382, 282]]
# 287
# 55
# GC_x, GC_y 287 55
# 246.07722365143832
# 110.25878649794764
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[138, 178], [138, 179]]
# min_legth is 1.0
# min_point is [[138, 178], [138, 179]]
# 必ず一回しかこのprintは通りません
# max_legth is 28.0
# max_point is [[115, 480], [115, 508]]
# 273
# 63
# GC_x, GC_y 273 63
# 445.9293666041742
# 177.341478509682
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[159, 151], [159, 154]]
# min_legth is 3.0
# min_point is [[159, 151], [159, 154]]
# 必ず一回しかこのprintは通りません
# max_legth is 384.0
# max_point is [[460, 542], [460, 158]]
# 288
# 102
# GC_x, GC_y 288 102
# 180.88670487352022
# 137.99275343292487
# resolution 4
# resolution 5
# resolution 6
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZH182017.png
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[147, 142], [147, 144]]
# min_legth is 2.0
# min_point is [[147, 142], [147, 144]]
# 必ず一回しかこのprintは通りません
# max_legth is 206.0
# max_point is [[388, 143], [182, 143]]
# 264
# 67
# GC_x, GC_y 264 67
# 76.0
# 138.97481786280562
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[170, 159], [170, 163]]
# min_legth is 4.0
# min_point is [[170, 159], [170, 163]]
# 必ず一回しかこのprintは通りません
# max_legth is 348.0
# max_point is [[163, 166], [163, 514]]
# 352
# 112
# GC_x, GC_y 352 112
# 196.562967010574
# 187.97074240423694
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[279, 389], [279, 391]]
# min_legth is 2.0
# min_point is [[279, 389], [279, 391]]
# 必ず一回しかこのprintは通りません
# max_legth is 174.0
# max_point is [[453, 389], [279, 389]]
# 265
# 131
# GC_x, GC_y 265 131
# 258.37956575549856
# 258.37956575549856
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[168, 159], [168, 161]]
# min_legth is 2.0
# min_point is [[168, 159], [168, 161]]
# 必ず一回しかこのprintは通りません
# max_legth is 359.0
# max_point is [[168, 514], [527, 514]]
# 104
# 259
# GC_x, GC_y 104 259
# 262.90872941003687
# 117.04699910719626
# resolution 4
# resolution 5
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[344, 257], [344, 261]]
# min_legth is 4.0
# min_point is [[344, 257], [344, 261]]
# 必ず一回しかこのprintは通りません
# max_legth is 261.0
# max_point is [[537, 549], [798, 549]]
# 266
# 402
# GC_x, GC_y 266 402
# 308.3018001893599
# 161.13658802394943
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[322, 72], [322, 73]]
# min_legth is 1.0
# min_point is [[322, 72], [322, 73]]
# 必ず一回しかこのprintは通りません
# max_legth is 267.0
# max_point is [[163, 416], [430, 416]]
# 318
# 537
# GC_x, GC_y 318 537
# 121.0
# 464.0172410589934
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[66, 197], [66, 200]]
# min_legth is 3.0
# min_point is [[66, 197], [66, 200]]
# 必ず一回しかこのprintは通りません
# max_legth is 432.0
# max_point is [[40, 431], [472, 431]]
# 551
# 314
# GC_x, GC_y 551 314
# 141.1736519326464
# 498.21782384816385
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[51, 196], [51, 198]]
# min_legth is 2.0
# min_point is [[51, 196], [51, 198]]
# 必ず一回しかこのprintは通りません
# max_legth is 236.0
# max_point is [[44, 202], [44, 438]]
# 264
# 265
# GC_x, GC_y 264 265
# 220.0
# 223.28905033610582
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[225, 296], [225, 299]]
# min_legth is 3.0
# min_point is [[225, 296], [225, 299]]
# 必ず一回しかこのprintは通りません
# max_legth is 244.0
# max_point is [[215, 518], [459, 518]]
# 304
# 213
# GC_x, GC_y 304 213
# 305.0
# 114.58621208504974
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[227, 49], [227, 52]]
# min_legth is 3.0
# min_point is [[227, 49], [227, 52]]
# 必ず一回しかこのprintは通りません
# max_legth is 150.0
# max_point is [[230, 491], [380, 491]]
# 322
# 526
# GC_x, GC_y 322 526
# 35.0
# 483.4263128957711
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[396, 175], [395, 176]]
# min_legth is 1.4142135623730951
# min_point is [[396, 175], [395, 176]]
# 必ず一回しかこのprintは通りません
# max_legth is 31.0
# max_point is [[417, 474], [417, 443]]
# 294
# 231
# GC_x, GC_y 294 231
# 245.0979396078229
# 115.00434774390054
# resolution 4
# resolution 5
# resolution 6
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[156, 213], [155, 214]]
# min_legth is 1.4142135623730951
# min_point is [[156, 213], [155, 214]]
# 必ず一回しかこのprintは通りません
# max_legth is 22.0
# max_point is [[655, 379], [655, 357]]
# 409
# 286
# GC_x, GC_y 409 286
# 256.04101233982027
# 263.32109676210905
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[307, 102], [307, 103]]
# min_legth is 1.0
# min_point is [[307, 102], [307, 103]]
# 必ず一回しかこのprintは通りません
# max_legth is 256.0
# max_point is [[660, 620], [660, 364]]
# 365
# 771
# GC_x, GC_y 365 771
# 331.40006035002466
# 670.5132362601055
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[38, 265], [38, 267]]
# min_legth is 2.0
# min_point is [[38, 265], [38, 267]]
# 必ず一回しかこのprintは通りません
# max_legth is 226.0
# max_point is [[31, 272], [31, 498]]
# 329
# 169
# GC_x, GC_y 329 169
# 315.29827148273426
# 306.42617381679395
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[326, 171], [325, 172]]
# min_legth is 1.4142135623730951
# min_point is [[326, 171], [325, 172]]
# 必ず一回しかこのprintは通りません
# max_legth is 167.0
# max_point is [[254, 529], [421, 529]]
# 277
# 196
# GC_x, GC_y 277 196
# 333.0
# 53.665631459994955
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[129, 166], [129, 169]]
# min_legth is 3.0
# min_point is [[129, 166], [129, 169]]
# 必ず一回しかこのprintは通りません
# max_legth is 130.0
# max_point is [[124, 252], [124, 382]]
# 329
# 411
# GC_x, GC_y 329 411
# 207.04105872990507
# 313.94904045083496
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[525, 176], [524, 177]]
# min_legth is 1.4142135623730951
# min_point is [[525, 176], [524, 177]]
# 必ず一回しかこのprintは通りません
# max_legth is 55.0
# max_point is [[157, 195], [157, 250]]
# 118
# 340
# GC_x, GC_y 118 340
# 98.08669634563088
# 437.49857142623904
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# resolution 75
# resolution 76
# resolution 77
# resolution 78
# resolution 79
# resolution 80
# resolution 81
# resolution 82
# resolution 83
# resolution 84
# resolution 85
# resolution 86
# resolution 87
# resolution 88
# resolution 89
# resolution 90
# resolution 91
# resolution 92
# resolution 93
# resolution 94
# resolution 95
# resolution 96
# resolution 97
# resolution 98
# resolution 99
# resolution 100
# resolution 101
# resolution 102
# resolution 103
# resolution 104
# resolution 105
# resolution 106
# resolution 107
# resolution 108
# resolution 109
# resolution 110
# resolution 111
# resolution 112
# resolution 113
# resolution 114
# resolution 115
# resolution 116
# resolution 117
# resolution 118
# resolution 119
# resolution 120
# resolution 121
# resolution 122
# resolution 123
# resolution 124
# resolution 125
# resolution 126
# resolution 127
# resolution 128
# resolution 129
# resolution 130
# resolution 131
# resolution 132
# resolution 133
# resolution 134
# resolution 135
# resolution 136
# resolution 137
# resolution 138
# resolution 139
# resolution 140
# resolution 141
# resolution 142
# resolution 143
# resolution 144
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[133, 228], [133, 248]]
# min_legth is 20.0
# min_point is [[133, 228], [133, 248]]
# 必ず一回しかこのprintは通りません
# max_legth is 335.0
# max_point is [[132, 249], [132, 584]]
# 282
# 209
# GC_x, GC_y 282 209
# 155.24174696260025
# 150.20652449211386
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/C4Q10Y021.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[107, 202], [107, 205]]
# min_legth is 3.0
# min_point is [[107, 202], [107, 205]]
# 必ず一回しかこのprintは通りません
# max_legth is 340.0
# max_point is [[447, 202], [107, 202]]
# 346
# 167
# GC_x, GC_y 346 167
# 35.0
# 241.54916683772686
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[151, 149], [151, 152]]
# min_legth is 3.0
# min_point is [[151, 149], [151, 152]]
# 必ず一回しかこのprintは通りません
# max_legth is 404.0
# max_point is [[555, 149], [151, 149]]
# 104
# 347
# GC_x, GC_y 104 347
# 203.5018427434995
# 200.58414693090776
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[360, 111], [360, 112]]
# min_legth is 1.0
# min_point is [[360, 111], [360, 112]]
# 必ず一回しかこのprintは通りません
# max_legth is 19.0
# max_point is [[379, 111], [360, 111]]
# 223
# 337
# GC_x, GC_y 223 337
# 264.2820463065927
# 263.4274093559742
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[249, 38], [249, 39]]
# min_legth is 1.0
# min_point is [[249, 38], [249, 39]]
# 必ず一回しかこのprintは通りません
# max_legth is 157.0
# max_point is [[196, 403], [353, 403]]
# 262
# 521
# GC_x, GC_y 262 521
# 118.0
# 482.17527933314875
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[314, 50], [313, 51]]
# min_legth is 1.4142135623730951
# min_point is [[314, 50], [313, 51]]
# 必ず一回しかこのprintは通りません
# max_legth is 78.0
# max_point is [[392, 50], [314, 50]]
# 273
# 367
# GC_x, GC_y 273 367
# 319.64042297556796
# 318.5215848258953
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[322, 33], [321, 34]]
# min_legth is 1.4142135623730951
# min_point is [[322, 33], [321, 34]]
# 必ず一回しかこのprintは通りません
# max_legth is 89.0
# max_point is [[194, 44], [194, 133]]
# 306
# 496
# GC_x, GC_y 306 496
# 379.8855090681928
# 462.24344235478344
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[61, 154], [61, 155]]
# min_legth is 1.0
# min_point is [[61, 154], [61, 155]]
# 必ず一回しかこのprintは通りません
# max_legth is 296.0
# max_point is [[425, 462], [425, 166]]
# 502
# 314
# GC_x, GC_y 502 314
# 77.0
# 468.78779847602686
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[201, 41], [201, 44]]
# min_legth is 3.0
# min_point is [[201, 41], [201, 44]]
# 必ず一回しかこのprintは通りません
# max_legth is 373.0
# max_point is [[195, 47], [195, 420]]
# 276
# 388
# GC_x, GC_y 276 388
# 81.0
# 352.08095659947304
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[479, 150], [478, 151]]
# min_legth is 1.4142135623730951
# min_point is [[479, 150], [478, 151]]
# 必ず一回しかこのprintは通りません
# max_legth is 263.0
# max_point is [[537, 419], [537, 156]]
# 183
# 119
# GC_x, GC_y 183 119
# 355.92836357896516
# 296.73051747334654
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[346, 42], [345, 43]]
# min_legth is 1.4142135623730951
# min_point is [[346, 42], [345, 43]]
# 必ず一回しかこのprintは通りません
# max_legth is 95.0
# max_point is [[380, 334], [380, 239]]
# 328
# 380
# GC_x, GC_y 328 380
# 69.42621983083913
# 337.4285109471338
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[166, 73], [166, 75]]
# min_legth is 2.0
# min_point is [[166, 73], [166, 75]]
# 必ず一回しかこのprintは通りません
# max_legth is 466.0
# max_point is [[160, 79], [160, 545]]
# 330
# 73
# GC_x, GC_y 330 73
# 170.10584939971935
# 164.0
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[215, 165], [215, 203]]
# min_legth is 38.0
# min_point is [[215, 165], [215, 203]]
# 必ず一回しかこのprintは通りません
# max_legth is 224.0
# max_point is [[439, 165], [215, 165]]
# 229
# 234
# GC_x, GC_y 229 234
# 69.0
# 34.0147027033899
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZH182037.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZY181050.png
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[195, 67], [194, 68]]
# min_legth is 1.4142135623730951
# min_point is [[195, 67], [194, 68]]
# 必ず一回しかこのprintは通りません
# max_legth is 299.0
# max_point is [[494, 67], [195, 67]]
# 544
# 411
# GC_x, GC_y 544 411
# 347.6147292621531
# 490.03775364761435
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[128, 143], [128, 235]]
# min_legth is 92.0
# min_point is [[128, 143], [128, 235]]
# 必ず一回しかこのprintは通りません
# max_legth is 182.0
# max_point is [[310, 143], [128, 143]]
# 294
# 221
# GC_x, GC_y 294 221
# 78.0
# 166.0
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[311, 111], [310, 112]]
# min_legth is 1.4142135623730951
# min_point is [[311, 111], [310, 112]]
# 必ず一回しかこのprintは通りません
# max_legth is 295.0
# max_point is [[82, 124], [82, 419]]
# 243
# 462
# GC_x, GC_y 243 462
# 166.6433316997713
# 356.35515991774275
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[43, 204], [43, 206]]
# min_legth is 2.0
# min_point is [[43, 204], [43, 206]]
# 必ず一回しかこのprintは通りません
# max_legth is 362.0
# max_point is [[42, 473], [404, 473]]
# 314
# 167
# GC_x, GC_y 314 167
# 306.0
# 273.5141678231678
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[101, 114], [100, 115]]
# min_legth is 1.4142135623730951
# min_point is [[101, 114], [100, 115]]
# 必ず一回しかこのprintは通りません
# max_legth is 140.0
# max_point is [[241, 114], [101, 114]]
# 175
# 172
# GC_x, GC_y 175 172
# 58.0
# 94.02127418834527
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[330, 207], [330, 223]]
# min_legth is 16.0
# min_point is [[330, 207], [330, 223]]
# 必ず一回しかこのprintは通りません
# max_legth is 16.0
# max_point is [[330, 207], [330, 223]]
# 303
# 335
# GC_x, GC_y 303 335
# 115.20850663036997
# 115.20850663036997
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# resolution 75
# resolution 76
# resolution 77
# resolution 78
# resolution 79
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/C1K183004.png
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[137, 210], [137, 212]]
# min_legth is 2.0
# min_point is [[137, 210], [137, 212]]
# 必ず一回しかこのprintは通りません
# max_legth is 135.0
# max_point is [[131, 215], [131, 350]]
# 103
# 233
# GC_x, GC_y 103 233
# 28.0
# 39.96248240537617
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[189, 199], [189, 200]]
# min_legth is 1.0
# min_point is [[189, 199], [189, 200]]
# 必ず一回しかこのprintは通りません
# max_legth is 320.0
# max_point is [[183, 205], [183, 525]]
# 286
# 90
# GC_x, GC_y 286 90
# 154.38264151127873
# 145.91093173576817
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[113, 246], [113, 278]]
# min_legth is 32.0
# min_point is [[113, 246], [113, 278]]
# 必ず一回しかこのprintは通りません
# max_legth is 432.0
# max_point is [[54, 536], [486, 536]]
# 284
# 69
# GC_x, GC_y 284 69
# 467.0
# 246.1097316239242
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[240, 236], [240, 239]]
# min_legth is 3.0
# min_point is [[240, 236], [240, 239]]
# 必ず一回しかこのprintは通りません
# max_legth is 279.0
# max_point is [[352, 522], [352, 243]]
# 313
# 178
# GC_x, GC_y 313 178
# 75.8023746329889
# 93.23625904121208
# resolution 4
# resolution 5
# resolution 6
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[54, 198], [54, 201]]
# min_legth is 3.0
# min_point is [[54, 198], [54, 201]]
# 必ず一回しかこのprintは通りません
# max_legth is 383.0
# max_point is [[437, 198], [54, 198]]
# 501
# 275
# GC_x, GC_y 501 275
# 100.12492197250393
# 453.08387744434253
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[259, 112], [256, 115]]
# min_legth is 4.242640687119285
# min_point is [[259, 112], [256, 115]]
# 必ず一回しかこのprintは通りません
# max_legth is 18.0
# max_point is [[277, 112], [259, 112]]
# 425
# 451
# GC_x, GC_y 425 451
# 369.8986347636336
# 376.10769734213096
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[116, 205], [115, 206]]
# min_legth is 1.4142135623730951
# min_point is [[116, 205], [115, 206]]
# 必ず一回しかこのprintは通りません
# max_legth is 43.0
# max_point is [[392, 348], [392, 305]]
# 313
# 200
# GC_x, GC_y 313 200
# 131.40015220691336
# 197.06344156134085
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[342, 195], [342, 403]]
# min_legth is 208.0
# min_point is [[342, 195], [342, 403]]
# 必ず一回しかこのprintは通りません
# max_legth is 208.0
# max_point is [[342, 195], [342, 403]]
# 271
# 297
# GC_x, GC_y 271 297
# 71.0
# 71.0
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[184, 76], [184, 254]]
# min_legth is 178.0
# min_point is [[184, 76], [184, 254]]
# 必ず一回しかこのprintは通りません
# max_legth is 414.0
# max_point is [[349, 491], [349, 77]]
# 253
# 403
# GC_x, GC_y 253 403
# 96.0
# 164.20109622045769
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[533, 188], [532, 189]]
# min_legth is 1.4142135623730951
# min_point is [[533, 188], [532, 189]]
# 必ず一回しかこのprintは通りません
# max_legth is 15.0
# max_point is [[311, 259], [311, 274]]
# 108
# 346
# GC_x, GC_y 108 346
# 215.3903433304288
# 452.133829745132
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[392, 188], [392, 327]]
# min_legth is 139.0
# min_point is [[392, 188], [392, 327]]
# 必ず一回しかこのprintは通りません
# max_legth is 204.0
# max_point is [[389, 190], [185, 190]]
# 341
# 278
# GC_x, GC_y 341 278
# 88.0
# 51.0
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[271, 125], [270, 126]]
# min_legth is 1.4142135623730951
# min_point is [[271, 125], [270, 126]]
# 必ず一回しかこのprintは通りません
# max_legth is 227.0
# max_point is [[339, 433], [566, 433]]
# 190
# 413
# GC_x, GC_y 190 413
# 150.3362896974646
# 297.9412693803932
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[296, 139], [296, 142]]
# min_legth is 3.0
# min_point is [[296, 139], [296, 142]]
# 必ず一回しかこのprintは通りません
# max_legth is 381.0
# max_point is [[289, 146], [289, 527]]
# 242
# 117
# GC_x, GC_y 242 117
# 55.226805085936306
# 58.309518948453004
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# output_path is ./tochi_test37/removenoisefun.png
# 土地が見つかりませんでした tochi/CZ2177G39.png
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[48, 225], [48, 227]]
# min_legth is 2.0
# min_point is [[48, 225], [48, 227]]
# 必ず一回しかこのprintは通りません
# max_legth is 411.0
# max_point is [[48, 422], [459, 422]]
# 535
# 240
# GC_x, GC_y 535 240
# 197.2308292331602
# 487.1734803948179
# resolution 4
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[246, 233], [246, 236]]
# min_legth is 3.0
# min_point is [[246, 233], [246, 236]]
# 必ず一回しかこのprintは通りません
# max_legth is 304.0
# max_point is [[550, 233], [246, 233]]
# 336
# 134
# GC_x, GC_y 336 134
# 99.0
# 133.79461872586654
# resolution 4
# resolution 5
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[148, 187], [148, 189]]
# min_legth is 2.0
# min_point is [[148, 187], [148, 189]]
# 必ず一回しかこのprintは通りません
# max_legth is 393.0
# max_point is [[136, 435], [529, 435]]
# 126
# 391
# GC_x, GC_y 126 391
# 45.12205669071391
# 203.19448811422026
# resolution 4
# resolution 5
# resolution 6
# resolution 7
# resolution 8
# resolution 9
# resolution 10
# resolution 11
# resolution 12
# resolution 13
# resolution 14
# resolution 15
# resolution 16
# resolution 17
# resolution 18
# resolution 19
# resolution 20
# resolution 21
# resolution 22
# resolution 23
# resolution 24
# resolution 25
# resolution 26
# resolution 27
# resolution 28
# resolution 29
# resolution 30
# resolution 31
# resolution 32
# resolution 33
# resolution 34
# resolution 35
# resolution 36
# resolution 37
# resolution 38
# resolution 39
# resolution 40
# resolution 41
# resolution 42
# resolution 43
# resolution 44
# resolution 45
# resolution 46
# resolution 47
# resolution 48
# resolution 49
# resolution 50
# resolution 51
# resolution 52
# resolution 53
# resolution 54
# resolution 55
# resolution 56
# resolution 57
# resolution 58
# resolution 59
# resolution 60
# resolution 61
# resolution 62
# resolution 63
# resolution 64
# resolution 65
# resolution 66
# resolution 67
# resolution 68
# resolution 69
# resolution 70
# resolution 71
# resolution 72
# resolution 73
# resolution 74
# resolution 75
# resolution 76
# resolution 77
# resolution 78
# resolution 79
# output_path is ./tochi_test37/removenoisefun.png
# min_point is [[239, 252], [239, 253]]
# min_legth is 1.0
# min_point is [[239, 252], [239, 253]]
# 必ず一回しかこのprintは通りません
# max_legth is 217.0
# max_point is [[205, 429], [422, 429]]
# 293
# 403
# GC_x, GC_y 293 403
# 26.0
# 159.42396306703708

# %%
output_dir='./tochi'
fp=open('./tochi/image_list.txt','r')
line =  fp.readline()


while line:
   
    line = line.strip()
    
    myfile = './tochi/' + line
    
    print (myfile)
    run(myfile,line)
    line =  fp.readline()


print("out of while")

# %%
print("all program is done")
